# %% [markdown]
# # Prediction Using Unsupervised ML

# %% [markdown]
# ## Author : Harshal Honde

# %% [markdown]
# ## GRIPAPRIL22 @The Sparks Foundation
#
# ## Data Science & Business Analytics Intern
#
# In this task we have to predict the optimum number of clusters and represents it Visually.
#
# Data set:https://bit.ly/3kXTdox

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv()
# Out:
#   File "/tmp/wsuser/ipykernel_254/3065982852.py", line 1
#     df = pd.read_csv("C:\Users\harshal\Desktop\Github\Iris.csv")
#                                                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df.head()
# Out:
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="zx15EUaqrDpQT4hWZ4EV9A">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>Iris.csv - Google Drive</title><meta property="og:title" content="Iris.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/11Iq7YvbWZbt8VXjfm06brx66b10YiwK-/view?usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300  \
# 0                                               try{
# 1                                             var ja
# 2  _.ha=function(){return _.p("Safari")&&!(_.fa()...
# 3  _.la=function(a){var b=a.length;if(0<b){for(va...
# 4  ua=function(a){return Array.isArray(a)?!!(sa(a...
#
#                                                  400  \
# 0                                                NaN
# 1                                                 ra
# 2                                                NaN
# 3  d=0;d<b;d++)c[d]=a[d];return c}return[]};_.ma=...
# 4  2)};wa=function(a){return null!==a&&"object"==...
#
#                                                  500  \
# 0                                                NaN
# 1                                                 sa
# 2                                                NaN
# 3  b){Object.isFrozen(a)||(qa?a[qa]|=b:void 0!==a...
# 4                                    configurable:!1
#
#   700" nonce="zx15EUaqrDpQT4hWZ4EV9A"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.1cNZp678xHs.L.X.O/d=0/rs=AO0039uEuG2OOqo0iOcuQEKvzmw_kPnk5g" nonce="zx15EUaqrDpQT4hWZ4EV9A"><script nonce="JD2jjL+9/BSPK4Zl5uyKAg">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 0                                                NaN
# 1                                                 ua
# 2                                                NaN
# 3                                       {Sd:{value:b
# 4                                        writable:!1
#
#                                 docs-fwds:"docs_sdf" docs-crs:"docs_crs_nfd"  \
# 0                                                NaN                     NaN
# 1                                                 va                      wa
# 2                                                NaN                     NaN
# 3                                    configurable:!0             writable:!0
# 4  enumerable:!1}};_.Ba=function(a){switch(typeof...                     NaN
#
#                                          docs-shdn:0    docs-tfh:""  \
# 0                                                NaN            NaN
# 1                                                 xa             Ea
# 2                                                NaN            NaN
# 3  enumerable:!1}}))};sa=function(a){var b;qa?b=a...  1);return a};
# 4                                                NaN            NaN
#
#   info_params:{} docos-eddmh:false  ... null.192 1.60 5.2  jp 173] [[null.2  \
# 0            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
# 1             Fa                Da  ...      NaN  NaN NaN NaN  NaN      NaN
# 2            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
# 3            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
# 4            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
#
#   null.193 null.194  \
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
#
#   https://www.gstatic.com/og/_/js/k=og.qtm.en_US.dPyW-2_N-wg.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTshJ7rMgELB7P1bkV0inIKSumTmkw]]]]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 757 columns]
